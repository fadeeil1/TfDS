# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# <a href="https://dataplatform.cloud.ibm.com/gallery">IBM Cloud Gallery</a>

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Fadeev Ilya**<br>
# Now I work as an IT specialist, and I plan to become a data analyst

# %% [markdown]
# *I am interested in data science because I consider this profession to be a good development of myself, taking into account my background. In particular, I have an engineering degree, now I am engaged in IT and very often ask questions like "why is this so?" :)*

# %% [markdown]
# ### Python program to Plot Perfect Heart Shape

# %%
# importing libraries
import numpy as np
from matplotlib import pyplot as plt

# Creating equally spaced 100 data in range 0 to 2*pi
theta = np.linspace(0, 2 * np.pi, 100)

# Generating x and y data
x = 16 * ( np.sin(theta) ** 3 )
y = 13 * np.cos(theta) - 5* np.cos(2*theta) - 2 * np.cos(3*theta) - np.cos(4*theta)

# Plotting
plt.plot(x, y)
plt.title('Heart Shape')
plt.show()

# %% [markdown]
# - Bulleted item 1
# - Bulleted item 2
# - Bulleted item 3

# %% [markdown]
# 1. Numbered item 1
# 1. Numbered item 2
# 1. Numbered item 3

# %% [markdown]
# [My LinkedIn](https://www.linkedin.com/in/fadeyef)

# %% [markdown]
# |Column 1|Column 2|Column 3|
# |---|---|---|
# |Data 1|Data 2|Data 3|
